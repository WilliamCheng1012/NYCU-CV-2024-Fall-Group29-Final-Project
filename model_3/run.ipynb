# %%
# !python train.py \
    --dataroot "/home/hpc/Project/312510232/Final_Project/DL_TermProject/data/" \
    --name IBCLN \
    --model IBCLN \
    --dataset_mode dltermproject \
    --no_flip   \
    --gpu_id 1 \
    --display_id -1 \
    --save_epoch_freq 1 \
    --dataset_size 0
# Out:
# /opt/anaconda3/envs/dl_final/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/opt/anaconda3/envs/dl_final/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# ----------------- Options ---------------
#                batch_size: 2
#                     beta1: 0.5
#                blurKernel: 5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: /home/hpc/Project/312510232/Final_Project/DL_TermProject/data/	[default: None]
#              dataset_mode: dltermproject                 	[default: unaligned]
# ...

# %%
# !python test.py \
    --dataroot "/home/hpc/Project/312510232/Final_Project/DL_TermProject/data/testing_set/testdata_reflection_synthetic_table2" \
    --results_dir "./results/testdata_reflection_synthetic_table2" \
    --name IBCLN \
    --model IBCLN \
    --dataset_mode test \
    --preprocess "" \
    --no_flip \
    --epoch final \
    --gpu_ids 1 
    # --results_dir "./results/SIR2/Wildscene" 
    # --max_dataset_size 99
    # --phase test


    # --dataroot "/home/hpc/Project/312510232/Final_Project/DL_TermProject/data/testing_set/testdata_reflection_synthetic_table2" \
    # --results_dir "./results/testdata_reflection_synthetic_table2" \
    # --dataroot "/home/hpc/Project/312510232/Final_Project/DL_TermProject/data/testing_set/Berkeley real dataset" \
    # --results_dir "./results/Berkeley real dataset" \
    # --dataroot "/home/hpc/Project/312510232/Final_Project/DL_TermProject/data/testing_set/Natural Reflection Dataset(NRD)" \
    # --results_dir "./results/Natural Reflection Dataset(NRD)" \
    # --dataroot "/home/hpc/Project/312510232/Final_Project/DL_TermProject/data/testing_set/SIR2/PostcardDataset" \
    # --results_dir "./results/SIR2/PostcardDataset" 
    
    # --dataroot "/home/hpc/Project/312510232/Final_Project/DL_TermProject/data/testing_set/SIR2/SolidObjectDataset" \
    # --results_dir "./results/SIR2/SolidObjectDataset" \
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 2
#                blurKernel: 5
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: /home/hpc/Project/312510232/Final_Project/DL_TermProject/data/testing_set/SIR2/Wildscene	[default: None]
#              dataset_mode: test                          	[default: unaligned]
#              dataset_size: 0
#           display_winsize: 256
#                     epoch: final                         	[default: latest]
#                      eval: False
#                   gpu_ids: 1                             	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
# ...

# %%
# !python eval.py
